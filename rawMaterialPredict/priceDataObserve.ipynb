# %%
import pandas as pd
from datetime import datetime, timedelta
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df=pd.read_pickle('/Users/benbilly3/Desktop/資策會專題/rawMaterialPricePrediction/RM_Price/rawMaterialPrice.pickle')
df2=df.reset_index()
#抽出月份
df2['YM']=df2['Date'].apply(lambda s:s.strftime('%Y%m'))
df2
# Out:
#          stock_id       Date    Open    High     Low   Close   Volume      YM
# 0          cmeNGF 1990-04-12    1.60    1.60    1.59    1.60      0.0  199004
# 1          cmeNGF 1990-04-16    1.60    1.60    1.59    1.60      0.0  199004
# 2          cmeNGF 1990-04-17    1.59    1.60    1.59    1.59      0.0  199004
# 3          cmeNGF 1990-04-18    1.58    1.59    1.58    1.58      0.0  199004
# 4          cmeNGF 1990-04-19    1.58    1.58    1.55    1.57      0.0  199004
# 5          cmeNGF 1990-04-20    1.56    1.56    1.54    1.54      0.0  199004
# 6          cmeNGF 1990-04-23    1.53    1.56    1.53    1.56      0.0  199004
# 7          cmeNGF 1990-04-24    1.54    1.56    1.54    1.56      0.0  199004
# 8          cmeNGF 1990-04-25    1.56    1.57    1.55    1.55      0.0  199004
# 9          cmeNGF 1990-04-26    1.56    1.56    1.56    1.56      0.0  199004
# 10         cmeNGF 1990-04-27    1.56    1.56    1.55    1.56      0.0  199004
# 11         cmeNGF 1990-04-30    1.57    1.57    1.57    1.57      0.0  199004
# 12         cmeNGF 1990-05-01    1.58    1.58    1.57    1.57      0.0  199005
# 13         cmeNGF 1990-05-02    1.58    1.58    1.58    1.58      0.0  199005
# 14         cmeNGF 1990-05-03    1.58    1.58    1.58    1.58      0.0  199005
# 15         cmeNGF 1990-05-04    1.57    1.58    1.57    1.58      0.0  199005
# 16         cmeNGF 1990-05-07    1.58    1.59    1.58    1.58      0.0  199005
# 17         cmeNGF 1990-05-08    1.58    1.59    1.58    1.58      0.0  199005
# 18         cmeNGF 1990-05-09    1.59    1.59    1.58    1.58      0.0  199005
# 19         cmeNGF 1990-05-10    1.58    1.58    1.57    1.57      0.0  199005
# 20         cmeNGF 1990-05-11    1.57    1.58    1.57    1.57      0.0  199005
# 21         cmeNGF 1990-05-14    1.56    1.56    1.56    1.56      0.0  199005
# 22         cmeNGF 1990-05-15    1.56    1.56    1.55    1.55      0.0  199005
# 23         cmeNGF 1990-05-16    1.56    1.58    1.56    1.57      0.0  199005
# 24         cmeNGF 1990-05-17    1.57    1.58    1.57    1.57      0.0  199005
# 25         cmeNGF 1990-05-18    1.57    1.57    1.54    1.55      0.0  199005
# 26         cmeNGF 1990-05-21    1.55    1.56    1.55    1.56      0.0  199005
# 27         cmeNGF 1990-05-22    1.56    1.56    1.56    1.56      0.0  199005
# 28         cmeNGF 1990-05-23    1.60    1.61    1.60    1.60      0.0  199005
# 29         cmeNGF 1990-05-24    1.60    1.60    1.60    1.60      0.0  199005
# ...           ...        ...     ...     ...     ...     ...      ...     ...
# 143492  CanolaOil 2019-06-10  452.40  459.20  452.00  454.40  18910.0  201906
# 143493  CanolaOil 2019-06-11  453.50  457.90  452.40  455.50  13690.0  201906
# 143494  CanolaOil 2019-06-12  452.60  459.40  452.60  457.50  15490.0  201906
# 143495  CanolaOil 2019-06-13  457.00  460.30  454.40  456.50  18230.0  201906
# 143496  CanolaOil 2019-06-14  456.50  459.50  454.40  454.90  11660.0  201906
# 143497  CanolaOil 2019-06-17  455.00  460.30  454.60  459.60  13410.0  201906
# 143498  CanolaOil 2019-06-18  459.60  462.80  457.30  460.50  13210.0  201906
# 143499  CanolaOil 2019-06-19  460.50  460.50  454.00  455.50   7820.0  201906
# 143500  CanolaOil 2019-06-20  454.60  456.70  450.50  455.80   9470.0  201906
# 143501  CanolaOil 2019-06-21  455.40  455.80  452.30  453.40   4640.0  201906
# 143502  CanolaOil 2019-06-24  451.30  454.60  450.60  452.10   4400.0  201906
# 143503  CanolaOil 2019-06-25  452.10  454.20  445.80  445.80   4760.0  201906
# 143504  CanolaOil 2019-06-26  445.20  445.20  439.60  440.80   4820.0  201906
# 143505  CanolaOil 2019-06-27  439.30  449.00  439.20  441.10   2690.0  201906
# 143506  CanolaOil 2019-06-28  439.80  452.10  439.80  452.00    720.0  201906
# 143507  CanolaOil 2019-07-02  447.90  448.60  447.90  449.30    200.0  201907
# 143508  CanolaOil 2019-07-03  449.30  449.30  449.30  450.20    150.0  201907
# 143509  CanolaOil 2019-07-04  449.70  449.70  449.70  449.70      0.0  201907
# 143510  CanolaOil 2019-07-05  442.00  442.00  439.00  438.80     80.0  201907
# 143511  CanolaOil 2019-07-08  438.40  438.40  438.40  438.40      0.0  201907
# 143512  CanolaOil 2019-07-09  434.00  434.00  434.00  441.00     20.0  201907
# 143513  CanolaOil 2019-07-10  448.90  448.90  448.90  446.10     20.0  201907
# 143514  CanolaOil 2019-07-11  448.10  448.10  448.10  448.10      0.0  201907
# 143515  CanolaOil 2019-07-12  448.10  448.10  448.10  448.10      0.0  201907
# 143516  CanolaOil 2019-07-15  450.10  450.60  446.00  446.90   6130.0  201907
# 143517  CanolaOil 2019-07-16  446.90  447.10  442.00  445.30   9140.0  201907
# 143518  CanolaOil 2019-07-17  445.10  447.00  442.00  444.10   7830.0  201907
# 143519  CanolaOil 2019-07-18  444.10  445.80  441.60  445.40  10980.0  201907
# 143520  CanolaOil 2019-07-19  445.40  451.50  444.00  449.60  19340.0  201907
# 143521  CanolaOil 2019-07-22  449.80  451.00  446.10  447.00  10780.0  201907
#
# [143522 rows x 8 columns]

# %% [markdown]
# # 波動率函式

# %%
maxNum=df2.groupby(['stock_id','YM'])['Open','High','Low','Close','Volume'].max()
minNum=df2.groupby(['stock_id','YM'])['Open','High','Low','Close','Volume'].min()
priceFluctuation=(maxNum['High']-minNum['Low'])/maxNum['High']*100
stock_id_list=priceFluctuation.index.get_level_values(0)
stock_id_list = list(dict.fromkeys(stock_id_list))#len(stock_id_list)=15

def CFMS(stock_id,groupbyIndex):
    CF=priceFluctuation[stock_id]
    CFMS=CF.groupby([groupbyIndex]).mean()
    CFMSdf=pd.DataFrame({'CF':CFMS})
    CFMSdf=CFMSdf.reset_index()
    CFMSdf['M']=CFMSdf[groupbyIndex].apply(lambda s:s[4:])
    return CFMSdf.groupby(['M'])['CF'].mean()

CFMS('cmeCorn','YM')
# Out:
# M
# 01     8.769497
# 02     6.477526
# 03     8.201342
# 04     7.170737
# 05     8.979340
# 06    11.256092
# 07    15.088211
# 08    10.415138
# 09    10.558601
# 10     9.447187
# 11     7.634372
# 12     9.118182
# Name: CF, dtype: float64

# %% [markdown]
# # 波動率月份分佈繪圖

# %%
#設定繪圖控制
fig, axs = plt.subplots(5,3, figsize=(30, 12), facecolor='ghostwhite', edgecolor='k')
fig.subplots_adjust(left=None, bottom=0.4, right=1.5, top=3,hspace = .3, wspace=.15)
plt.rcParams['font.size']=24
plt.rcParams['font.family']=['Arial Unicode MS']

#設定組圖變數
plotList=[[v,x] for v,x in zip(list(range(len(stock_id_list))),stock_id_list)]
axs = axs.ravel()

for i,j in plotList:
    #設定顏色
    dfa=pd.DataFrame({'pf':CFMS(j,'YM')}) 
    dfa['rank']=dfa['pf'].rank()#大小分級
    dfa['colors'] = ['indianred' if x>9 else 'royalblue' if x<4 else 'wheat' for x in dfa['rank']]
    
    axs[i].set_facecolor('snow')
    axs[i].bar(range(len(dfa['pf'])),dfa['pf'],color=dfa['colors'],linewidth=3.2,alpha=0.7)
    axs[i].set_xticks(range(len(dfa['pf'])))
    axs[i].set_xticklabels(dfa['pf'].index,fontsize='medium')
    axs[i].set_ylim(dfa['pf'].min()*0.8,dfa['pf'].max()*1.05)
    axs[i].set_xlabel('Month')
    axs[i].set_ylabel('%')
    axs[i].set_title('Price Fluctuation--'+j,fontsize='xx-large',color='darkslateblue')
    axs[i].grid(color='b', linestyle='-', linewidth=0.5)

# %% [markdown]
# # 月份漲跌勝率分佈繪圖

# %%
df=pd.read_pickle('/Users/benbilly3/Desktop/資策會專題/rawMaterialPricePrediction/RM_Price/rawMaterialPrice.pickle')
df2=df.reset_index()
#抽出月份
df2['YM']=df2['Date'].apply(lambda s:s.strftime('%Y%m'))
df2['M']=df2['YM'].apply(lambda s:s[4:])
df2=df2.set_index('stock_id')
dataset=[]
for i in stock_id_list :
    df3=df2.loc[i]
    df3['YM']=df3['YM'].apply(lambda s:pd.to_numeric(s, errors='coerce'))
    df3['YM-2']=df3['YM'].shift(1)
    df3['newMonth']=(df3['YM']-df3['YM-2']).fillna(1)
    upAndDownS=df3[df3['newMonth']!=0]
    upAndDownS['nextMonthClose']=upAndDownS['Close'].shift(1)
    upAndDownS['upAndDownRatio']=round((upAndDownS['Close']/upAndDownS['nextMonthClose']-1)*100,2).shift(-1)
    upAndDownS=upAndDownS[~upAndDownS['upAndDownRatio'].isna()]
    upAndDownS['win']=upAndDownS['upAndDownRatio'].apply(lambda s:1 if s>0 else 0)
    dataset.append(upAndDownS)
upAndDownS=pd.concat(dataset)
upAndDownS
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                 Date       Open       High        Low      Close    Volume  \
# stock_id
# CanolaOil 2010-08-16  461.10001  469.39999  458.50000  468.10001   11660.0
# CanolaOil 2010-09-01  460.00000  466.20001  458.39999  464.79999   11450.0
# CanolaOil 2010-10-01  477.20001  482.50000  465.20001  468.00000   18080.0
# CanolaOil 2010-11-01  534.20001  535.50000  530.40002  535.00000     160.0
# CanolaOil 2010-12-01  537.90002  549.90002  536.90002  547.50000   10420.0
# CanolaOil 2011-01-04  579.50000  585.40002  569.00000  580.79999     140.0
# CanolaOil 2011-02-01  602.00000  610.40002  601.09998  609.00000   14780.0
# nfaSugar   201702  02  201701.0       1.0        20.51000           -6.53    0
# nfaSugar   201703  03  201702.0       1.0        20.84000          -15.09    0
# nfaSugar   201704  04  201703.0       1.0        19.48000           -2.18    0
# nfaSugar   201705  05  201704.0       1.0        16.54000          -12.05    0
# nfaSugar   201706  06  201705.0       1.0        16.18000           -2.18    0
# nfaSugar   201707  07  201706.0       1.0        14.23000            6.90    1
# nfaSugar   201708  08  201707.0       1.0        13.92000           -7.59    0
# nfaSugar   201709  09  201708.0       1.0        14.88000            4.07    1
# nfaSugar   201710  10  201709.0       1.0        13.75000            2.10    1
# nfaSugar   201711  11  201710.0       1.0        14.31000            2.53    1
# nfaSugar   201712  12  201711.0       1.0        14.61000            2.34    1
# nfaSugar   201801  01  201712.0      89.0        14.98000          -12.79    0
# nfaSugar   201802  02  201801.0       1.0        15.33000            2.54    1
# nfaSugar   201803  03  201802.0       1.0        13.37000           -8.68    0
# nfaSugar   201804  04  201803.0       1.0        13.71000           -6.63    0
# nfaSugar   201805  05  201804.0       1.0        12.52000            7.10    1
# nfaSugar   201806  06  201805.0       1.0        11.69000           -7.67    0
# nfaSugar   201807  07  201806.0       1.0        12.52000           -9.34    0
# nfaSugar   201808  08  201807.0       1.0        11.56000            1.53    1
# nfaSugar   201809  09  201808.0       1.0        10.48000            9.12    1
# nfaSugar   201810  10  201809.0       1.0        10.64000           13.61    1
# nfaSugar   201811  11  201810.0       1.0        11.61000           -2.12    0
# nfaSugar   201812  12  201811.0       1.0        13.19000           -7.59    0
# nfaSugar   201901  01  201812.0      89.0        12.91000            5.62    1
# nfaSugar   201902  02  201901.0       1.0        11.93000            0.16    1
# nfaSugar   201903  03  201902.0       1.0        12.60000            0.40    1
# nfaSugar   201904  04  201903.0       1.0        12.62000           -3.63    0
# nfaSugar   201905  05  201904.0       1.0        12.67000           -0.16    0
# nfaSugar   201906  06  201905.0       1.0        12.21000            3.12    1
# nfaSugar   201907  07  201906.0       1.0        12.19000           -3.58    0
#
# [7306 rows x 13 columns]

# %%
t1=upAndDownS.groupby(['stock_id','M'])['upAndDownRatio'].count()
t2=upAndDownS.groupby(['stock_id','M'])['upAndDownRatio'].sum()
t3=upAndDownS.groupby(['stock_id','M'])['win'].sum()
upAndDownMean=round(t2/t1,2)
winRatio=round(t3/t1*100,2)
# Out:
# stock_id   M
# CanolaOil  01    66.67
#            02    66.67
#            03    66.67
#            04    66.67
#            05    66.67
#            06    44.44
#            07    12.50
#            08    55.56
#            09    33.33
#            10    66.67
#            11    44.44
#            12    66.67
# cmeBO      01    50.85
#            02    45.76
#            03    40.68
#            04    45.76
#            05    38.98
#            06    43.10
#            07    42.86
#            08    49.12
#            09    48.28
#            10    57.89
#            11    52.54
#            12    53.45
# cmeCorn    01    50.85
#            02    45.76
#            03    69.49
#            04    47.46
#            05    55.93
#            06    45.76
#                  ...
# nfaCoffee  07    34.78
#            08    60.87
#            09    34.78
#            10    45.65
#            11    63.04
#            12    56.52
# nfaCotton  01    52.54
#            02    57.63
#            03    50.85
#            04    52.54
#            05    44.07
#            06    55.93
#            07    44.07
#            08    39.66
#            09    42.37
#            10    54.24
#            11    57.63
#            12    62.71
# nfaSugar   01    45.76
#            02    50.85
#            03    38.98
#            04    37.29
#            05    45.76
#            06    52.54
#            07    52.54
#            08    44.83
#            09    63.79
#            10    57.63
#            11    54.24
#            12    49.15
# Length: 180, dtype: float64

# %%
#設定繪圖控制
fig, axs = plt.subplots(5,3, figsize=(30, 12), facecolor='ghostwhite', edgecolor='k')
fig.subplots_adjust(left=None, bottom=0.4, right=1.5, top=3,hspace = .3, wspace=.15)
plt.rcParams['font.size']=24
plt.rcParams['font.family']=['Arial Unicode MS']

#設定組圖變數
plotList=[[v,x] for v,x in zip(list(range(len(stock_id_list))),stock_id_list)]
axs = axs.ravel()

for i,j in plotList:
    #設定顏色
    dfa=pd.DataFrame({'pf':winRatio[j]}) 
    dfa['rank']=dfa['pf'].rank()#大小分級
    dfa['colors'] = ['indianred' if x>9 else 'royalblue' if x<4 else 'wheat' for x in dfa['rank']]
    
    axs[i].set_facecolor('snow')
    axs[i].bar(range(len(dfa['pf'])),dfa['pf'],color=dfa['colors'],linewidth=3.2,alpha=0.7)
    axs[i].set_xticks(range(len(dfa['pf'])))
    axs[i].set_xticklabels(dfa['pf'].index,fontsize='medium')
    axs[i].set_ylim(dfa['pf'].min()*0.8,dfa['pf'].max()*1.05)
    axs[i].set_xlabel('Month')
    axs[i].set_ylabel('winRatio %')
    axs[i].set_title('Price Up&Down Statistic--'+j,fontsize='xx-large',color='darkslateblue')
    axs[i].grid(color='b', linestyle='-', linewidth=0.5)
    axs[i]=axs[i].twinx()
    
    axs[i].plot(range(len(upAndDownMean[j])),upAndDownMean[j],'--',color='#FF0000',label=j,linewidth=7)
    axs[i].set_ylabel('mean %')
    axs[i].axhline(y=0,color='seagreen',linewidth=5)

# %%
#設定繪圖控制
plt.subplots(1,1, figsize=(12, 3), facecolor='ghostwhite', edgecolor='k')
plt.subplots_adjust(left=None, bottom=0.4, right=1.5, top=3,hspace = .3, wspace=.15)
plt.rcParams['font.size']=24
plt.rcParams['font.family']=['Arial Unicode MS']

#設定組圖變數
stock_id_list=['cmeCorn']
plotList=[[v,x] for v,x in zip(list(range(len(stock_id_list))),stock_id_list)]
# plts = plts.ravel()

for i,j in plotList:
    #設定顏色
    dfa=pd.DataFrame({'pf':winRatio[j]}) 
    dfa['rank']=dfa['pf'].rank()#大小分級
    dfa['colors'] = ['indianred' if x>9 else 'royalblue' if x<4 else 'wheat' for x in dfa['rank']]
    
    plt.bar(range(len(dfa['pf'])),dfa['pf'],color=dfa['colors'],linewidth=3.2,alpha=0.7,label='當月勝率')
    plt.xticks(range(len(dfa['pf'])),dfa['pf'].index,fontsize='medium')
    plt.ylim(dfa['pf'].min()*0.8,dfa['pf'].max()*1.05)
    plt.ylabel('Month')
    plt.ylabel('winRatio %')
    plt.title('Price Up&Down Statistic--'+j,fontsize='xx-large',color='darkslateblue')
    plt.grid(color='b', linestyle='-', linewidth=0.5)
    plt.legend(loc='upper left')
    plt.twinx()
    
    plt.plot(range(len(upAndDownMean[j])),upAndDownMean[j],'--',color='#FF0000',label='當月平均漲跌幅',linewidth=7)
    plt.legend(loc='upper right')
    plt.ylabel('mean %')
    plt.axhline(y=0,color='seagreen',linewidth=5)
